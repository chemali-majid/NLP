# %% [markdown]
# <a href="https://colab.research.google.com/github/chemali-majid/NLP/blob/main/homeworkDL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# Génération des données
X, y = make_circles(n_samples=100, noise=0.1, factor=0.3, random_state=0)

# Affichage des dimensions
print('Dimensions de X:', X.shape)
print('Dimensions de y:', y.shape)

# Correction du scatter plot
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='summer')
plt.show()

def neural_network(X, y, n1=5, n_iter=3000, learning_rate=0.1):
    np.random.seed(0)

    m = X.shape[0]
    n0 = X.shape[1]  # nombre d'entrées (2 ici)
    n2 = 1           # sortie (classification binaire)

    # Initialisation des poids
    W1 = np.random.randn(n1, n0)
    b1 = np.zeros((n1, 1))
    W2 = np.random.randn(n2, n1)
    b2 = np.zeros((n2, 1))

    # Reshape de y
    y = y.reshape(1, m)

    # Fonction sigmoïde
    def sigmoid(z):
        return 1 / (1 + np.exp(-z))

    # Entraînement
    for i in range(n_iter):
        # Forward
        Z1 = W1.dot(X.T) + b1
        A1 = sigmoid(Z1)
        Z2 = W2.dot(A1) + b2
        A2 = sigmoid(Z2)

        # Backpropagation
        dZ2 = A2 - y
        dW2 = (1/m) * dZ2.dot(A1.T)
        db2 = (1/m) * np.sum(dZ2, axis=1, keepdims=True)

        dZ1 = W2.T.dot(dZ2) * A1 * (1 - A1)
        dW1 = (1/m) * dZ1.dot(X)
        db1 = (1/m) * np.sum(dZ1, axis=1, keepdims=True)

        # Mise à jour
        W1 -= learning_rate * dW1
        b1 -= learning_rate * db1
        W2 -= learning_rate * dW2
        b2 -= learning_rate * db2

    return {"W1": W1, "b1": b1, "W2": W2, "b2": b2}

    parametres = neural_network(X, y, n1=5, n_iter=3000, learning_rate=0.1)
# Out:
# Dimensions de X: (100, 2)
# Dimensions de y: (100,)

# %% [markdown]
# The program creates a circular dataset with two classes and trains a small neural network to classify the points. X stores the point coordinates, while y stores the labels: 0 or 1. The model has 2 input values, 5 hidden neurons, and 1 output neuron. Weights are randomly initialized and biases start at zero. The sigmoid function converts values into probabilities between 0 and 1. Training uses forward propagation to produce predictions, backpropagation to measure errors, and gradient descent to update the weights. The function finally returns the trained parameters.

# %% [markdown]
# The program generates a circular dataset with two classes and trains a small neural network to classify the points. X stores the point coordinates, and y stores the label 0 or 1. The model consists of 2 input values, 5 hidden neurons, and 1 output neuron. Weights are initialized randomly and biases are initialized to zero. Sigmoid function maps values into probabilities between 0 and 1. Training is done via forward propagation (to predict) , backpropagation (to measure errors) and gradient descent (to update weights) . Finally, the function returns the trained parameters.
